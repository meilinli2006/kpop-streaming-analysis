# %% [markdown]
# <a href="https://colab.research.google.com/github/meilinli2006/kpop-streaming-analysis/blob/main/notebooks/01_youtube_api_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-api-python-client

from googleapiclient.discovery import build
from google.colab import userdata

API_KEY = userdata.get( 'YOUTUBE_API_KEY' )
youtube = build('youtube', 'v3', developerKey=API_KEY)

#随便找一个MV，从网址watch?v= 后面那一串字符拿video id
request = youtube.videos().list(
    part="snippet,statistics",
    id="放你选的视频ID"
)
response = request.execute()
print(response)
# Out:
# ...
# {'kind': 'youtube#videoListResponse', 'etag': 'YIUPVpqNjppyCWOZfL-19bLb7uk', 'items': [], 'pageInfo': {'totalResults': 0, 'resultsPerPage': 0}}
